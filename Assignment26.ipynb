# %% [markdown]
# 1. Compare and contrast NLTK and spaCy in terms of features, ease of use,
# and performance.
#
# | Feature         | NLTK                                              | spaCy                                                            |
# | --------------- | ------------------------------------------------- | ---------------------------------------------------------------- |
# | Purpose         | Mainly for learning and research in NLP           | Designed for industrial and production NLP applications          |
# | Ease of Use     | Beginner-friendly with many tutorials             | Easy for practical tasks with simple APIs                        |
# | Performance     | Slower processing speed                           | Faster and optimized for large datasets                          |
# | Features        | Tokenization, stemming, tagging, parsing, corpora | Tokenization, POS tagging, NER, dependency parsing, word vectors |
# | Language Models | Limited built-in models                           | Pretrained efficient models available                            |
# | Flexibility     | Highly customizable for experiments               | More streamlined and production-ready                            |
# | Best For        | Education, prototyping, research                  | Real-world NLP applications and deployment                       |

# %% [markdown]
# 2. What is TextBlob and how does it simplify common NLP tasks like
# sentiment analysis and translation?
#
# TextBlob is a simple Python library built on top of NLTK and pattern that makes Natural Language Processing (NLP) easy for beginners.
#
# It simplifies common NLP tasks such as:
#
# * **Sentiment Analysis** → Detects positive, negative, or neutral emotions in text.
# * **Translation** → Translates text between languages.
# * **Tokenization** → Splits text into words or sentences.
# * **Part-of-Speech Tagging** → Identifies nouns, verbs, adjectives, etc.
# * **Spell Correction** → Corrects spelling mistakes.

# %% [markdown]
# 3. Explain the role of Standford NLP in academic and industry NLP Projects.
#
# Stanford NLP Group develops advanced NLP tools and research used in both academics and industry.
#
# ### Role in Academic Projects
#
# * Supports NLP research and experiments.
# * Provides tools for parsing, tagging, sentiment analysis, and named entity recognition.
# * Widely used for teaching and research in universities.
#
# ### Role in Industry Projects
#
# * Helps build applications like chatbots, search engines, translators, and text analyzers.
# * Offers accurate and scalable NLP models.
# * Powers real-world AI systems using libraries such as Stanford CoreNLP and Stanza.

# %% [markdown]
# 4.  Describe the architecture and functioning of a Recurrent Natural Network
# (RNN).
#
# A **Recurrent Neural Network (RNN)** is a deep learning model designed for processing sequential data such as text, speech, and time series.
#
# ### Architecture
#
# * An RNN contains:
#
#   * **Input layer** → receives data one step at a time.
#   * **Hidden layer** → stores information from previous steps using memory.
#   * **Output layer** → produces predictions.
#
# * The hidden state is passed from one time step to the next, creating a loop structure.
#
# ### Functioning
#
# 1. Input enters the network sequentially.
# 2. The hidden layer combines current input with previous hidden state.
# 3. The network remembers past information to understand context.
# 4. Output is generated for each sequence step or at the end.
#
# ### Formula
#
# h_t = f(Wx_t + Uh_{t-1} + b)
#
# Where:
#
# * (x_t) = current input
# * (h_{t-1}) = previous hidden state
# * (h_t) = current hidden state
#
# ### Uses
#
# * Language translation
# * Text prediction
# * Speech recognition
# * Sentiment analysis

# %% [markdown]
# 5. What is the key difference between LSTM and GRU networks in NLP
# applications?
#
# The key difference between **LSTM** and **GRU** networks is their internal structure and complexity.
#
# ### LSTM (Long Short-Term Memory)
#
# * Has **3 gates**: input, forget, and output gates.
# * Uses a separate **cell state** to store long-term information.
# * More powerful for complex sequence learning but slower.
#
# ### GRU (Gated Recurrent Unit)
#
# * Has **2 gates**: reset and update gates.
# * Combines hidden state and cell state into one.
# * Simpler, faster, and requires fewer parameters.

# %%
# Write a Python program using TextBlob to perform sentiment analysis on the following paragraph of text:

from textblob import TextBlob

# Given paragraph
text = """
I had a great experience using the new mobile banking app.
The interface is intuitive, and customer support was quick
to resolve my issue. However, the app did crash once
during a transaction, which was frustrating.
"""

# Create TextBlob object
blob = TextBlob(text)

# Perform sentiment analysis
sentiment = blob.sentiment

# Print results
print("Polarity:", sentiment.polarity)
print("Subjectivity:", sentiment.subjectivity)
# Out:
# Polarity: 0.21742424242424244
# Subjectivity: 0.6511363636363636

# %%
# Given the sample paragraph below, perform string tokenization and frequency distribution using Python and NLTK:

import nltk
from nltk.tokenize import word_tokenize
from nltk.probability import FreqDist

# Download tokenizer resources
nltk.download('punkt')

# Sample paragraph
text = """
Natural Language Processing (NLP) is a fascinating field that combines linguistics,
computer science, and artificial intelligence. It enables machines to understand,
interpret, and generate human language. Applications of NLP include chatbots,
sentiment analysis, and machine translation. As technology advances, the role of NLP
in modern solutions is becoming increasingly critical.
"""

# Tokenization
tokens = word_tokenize(text)

# Frequency Distribution
freq_dist = FreqDist(tokens)

# Print tokens
print("Tokens:")
print(tokens)

# Print frequency distribution
print("\nFrequency Distribution:")
print(freq_dist.most_common(10))
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# ---------------------------------------------------------------------------
# LookupError                               Traceback (most recent call last)
# /tmp/ipykernel_1319/2476444893.py in <cell line: 0>()
#      18
#      19 # Tokenization
# ---> 20 tokens = word_tokenize(text)
#      21
#      22 # Frequency Distribution
#
# /usr/local/lib/python3.12/dist-packages/nltk/tokenize/__init__.py in word_tokenize(text, language, preserve_line)
#     140     :type preserve_line: bool
#     141     """
# --> 142     sentences = [text] if preserve_line else sent_tokenize(text, language)
#     143     return [
#     144         token for sent in sentences for token in _treebank_word_tokenizer.tokenize(sent)
#
# /usr/local/lib/python3.12/dist-packages/nltk/tokenize/__init__.py in sent_tokenize(text, language)
#     117     :param language: the model name in the Punkt corpus
# ...

# %%
# Implement a basic LSTM model in Keras for a text classification task usingthe following dummy dataset. Your model should classify sentences as either positive (1) or negative (0).

import numpy as np
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding, LSTM, Dense

# Dataset
texts = [
    "I love this project",          # Positive
    "This is an amazing experience",# Positive
    "I hate waiting in line",       # Negative
    "This is the worst service",    # Negative
    "Absolutely fantastic!"         # Positive
]

labels = [1, 1, 0, 0, 1]

# Tokenization
tokenizer = Tokenizer()
tokenizer.fit_on_texts(texts)

# Convert text to sequences
sequences = tokenizer.texts_to_sequences(texts)

# Padding sequences
max_length = max(len(seq) for seq in sequences)
X = pad_sequences(sequences, maxlen=max_length, padding='post')

# Labels
y = np.array(labels)

# Vocabulary size
vocab_size = len(tokenizer.word_index) + 1

# Build LSTM Model
model = Sequential([
    Embedding(input_dim=vocab_size, output_dim=8, input_length=max_length),
    LSTM(16),
    Dense(1, activation='sigmoid')
])

# Compile model
model.compile(
    loss='binary_crossentropy',
    optimizer='adam',
    metrics=['accuracy']
)

# Train model
model.fit(X, y, epochs=20, verbose=1)

# Evaluate model
loss, accuracy = model.evaluate(X, y, verbose=0)

print("\nAccuracy:", accuracy)
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/embedding.py:100: UserWarning: Argument `input_length` is deprecated. Just remove it.
#   warnings.warn(
# Epoch 1/20
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 3s 3s/step - accuracy: 0.2000 - loss: 0.6959
# Epoch 2/20
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - accuracy: 0.4000 - loss: 0.6947
# Epoch 3/20
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.6000 - loss: 0.6935
# Epoch 4/20
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.6000 - loss: 0.6924
# Epoch 5/20
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.6000 - loss: 0.6913
# Epoch 6/20
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 0.6000 - loss: 0.6902
# Epoch 7/20
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - accuracy: 0.6000 - loss: 0.6892
# Epoch 8/20
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - accuracy: 0.6000 - loss: 0.6882
# Epoch 9/20
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - accuracy: 0.6000 - loss: 0.6872
# Epoch 10/20
# ...

# %%
# Using spaCy, build a simple NLP pipeline that includes tokenization,lemmatization, and entity recognition. Use the following paragraph as your dataset:

import spacy

# Load English language model
nlp = spacy.load("en_core_web_sm")

# Sample paragraph
text = """
Homi Jehangir Bhaba was an Indian nuclear physicist who played a key role
in the development of India’s atomic energy program. He was the founding
director of the Tata Institute of Fundamental Research (TIFR) and was
instrumental in establishing the Atomic Energy Commission of India.
"""

# Process text
doc = nlp(text)

# Print Tokens and Lemmas
print("Tokens and Lemmas:\n")
for token in doc:
    print(f"{token.text:<15} -> {token.lemma_}")

# Print Named Entities
print("\nNamed Entities:\n")
for ent in doc.ents:
    print(f"{ent.text:<50} {ent.label_}")
# Out:
# Tokens and Lemmas:
#
#
#                ->
#
# Homi            -> Homi
# Jehangir        -> Jehangir
# Bhaba           -> Bhaba
# was             -> be
# an              -> an
# Indian          -> indian
# nuclear         -> nuclear
# physicist       -> physicist
# who             -> who
# played          -> play
# a               -> a
# key             -> key
# role            -> role
#
#                ->
#
# in              -> in
# the             -> the
# development     -> development
# of              -> of
# India           -> India
# ’s              -> ’s
# atomic          -> atomic
# energy          -> energy
# program         -> program
# .               -> .
# He              -> he
# was             -> be
# the             -> the
# founding        -> founding
#
#                ->
#
# director        -> director
# of              -> of
# the             -> the
# Tata            -> Tata
# Institute       -> Institute
# of              -> of
# Fundamental     -> Fundamental
# ...

# %%
# You are working on a chatbot for a mental health platform. Explain how you would leverage LSTM or GRU networks along with libraries like spaCy or Stanford NLP to understand and respond to user input effectively. Detail your architecture, data preprocessing pipeline, and any ethical considerations.

import numpy as np
import spacy
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding, LSTM, Dense
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences

# Load spaCy model
nlp = spacy.load("en_core_web_sm")

# Sample dataset
texts = [
    "I feel very anxious today",
    "I am happy and relaxed",
    "I feel stressed and tired",
    "Today is a wonderful day"
]

labels = [1, 0, 1, 0]   # 1 = Negative emotion, 0 = Positive emotion

# Preprocessing using spaCy
processed_texts = []

for text in texts:
    doc = nlp(text)
    tokens = [token.lemma_.lower() for token in doc if not token.is_stop]
    processed_texts.append(" ".join(tokens))

# Tokenization
tokenizer = Tokenizer()
tokenizer.fit_on_texts(processed_texts)

sequences = tokenizer.texts_to_sequences(processed_texts)

# Padding
X = pad_sequences(sequences, maxlen=5)

y = np.array(labels)

# Build LSTM Model
model = Sequential([
    Embedding(input_dim=50, output_dim=8, input_length=5),
    LSTM(16),
    Dense(1, activation='sigmoid')
])

# Compile model
model.compile(
    optimizer='adam',
    loss='binary_crossentropy',
    metrics=['accuracy']
)

# Train model
model.fit(X, y, epochs=10, verbose=1)

# Prediction Example
test_text = ["I feel lonely and stressed"]

# Preprocess test text
doc = nlp(test_text[0])
processed = " ".join(
    [token.lemma_.lower() for token in doc if not token.is_stop]
)

seq = tokenizer.texts_to_sequences([processed])
padded = pad_sequences(seq, maxlen=5)

prediction = model.predict(padded)

print("Prediction Score:", prediction[0][0])
# Out:
# Epoch 1/10
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/embedding.py:100: UserWarning: Argument `input_length` is deprecated. Just remove it.
#   warnings.warn(
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step - accuracy: 0.2500 - loss: 0.6950
# Epoch 2/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.5000 - loss: 0.6945
# Epoch 3/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.5000 - loss: 0.6940
# Epoch 4/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 0.7500 - loss: 0.6935
# Epoch 5/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 0.7500 - loss: 0.6930
# Epoch 6/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - accuracy: 0.7500 - loss: 0.6926
# Epoch 7/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.7500 - loss: 0.6921
# Epoch 8/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 0.7500 - loss: 0.6916
# Epoch 9/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.7500 - loss: 0.6911
# Epoch 10/10
# ...
